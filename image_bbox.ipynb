# %% [markdown]
# <a href="https://colab.research.google.com/github/chellabeatrixkiddo/keras-frcnn/blob/master/image_bbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# %%
''' ## Uncomment the following : only when the repo is being cloned the first time

os.chdir("/content/drive/My Drive/deepfashion2")

# !git clone https://github.com/chellabeatrixkiddo/keras-frcnnkeras-frcnn.git
  
## moving train.zip and test.zip into the cloned git repo directory

source = '/content/drive/My Drive/deepfashion2/train.zip'
destination = '/content/drive/My Drive/deepfashion2/keras-frcnn/'
shutil.move(source, destination)

source = '/content/drive/My Drive/deepfashion2/test.zip'
destination = '/content/drive/My Drive/deepfashion2/keras-frcnn/'
shutil.move(source, destination)

source = '/content/drive/My Drive/deepfashion2/annotate.txt'
destination = '/content/drive/My Drive/deepfashion2/keras-frcnn/'
shutil.move(source, destination)

os.chdir("/content/drive/My Drive/deepfashion2/keras-frcnn/")

## unzip train.zip
# !unzip train.zip

## unzip test.zip
# !unzip test.zip

'''
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 178.49 KiB | 1.02 MiB/s, done.
# Resolving deltas: 100% (396/396), done.

# %%
os.chdir("/content/drive/My Drive/deepfashion2/keras-frcnn/")

# %%
## Training

# !python train_frcnn.py -o simple -p annotate.txt
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'Bottom': 1280, 'Top': 1280, 'bg': 0}
# Num classes (including bg) = 3
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 1024
# Num val samples 256
# WARNING: Logging before flag parsing goes to stderr.
# W0903 13:25:38.675480 139769962604416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0903 13:25:38.708003 139769962604416 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
## create a directory to store the result images after inferencing
try:
  os.mkdir("./results_imgs") 
except OSError as error:
  print("Folder exists")

# %%
## Inferencing

# !python test_frcnn.py -p test
# Out:
# Using TensorFlow backend.
# {0: 'Top', 1: 'Bottom', 2: 'bg'}
# WARNING: Logging before flag parsing goes to stderr.
# W0904 06:47:57.865129 139625721329536 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0904 06:47:57.876327 139625721329536 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0904 06:47:57.881466 139625721329536 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
## Commit and Push the changes to the repository
'''!git config user.email "m.chellaa@gmail.com"
# !git config user.name "chellabeatrixkiddo"
# !git add keras_frcnn/RoiPoolingConv.py keras_frcnn/data_generators.py keras_frcnn/losses.py keras_frcnn/resnet.py keras_frcnn/roi_helpers.py keras_frcnn/simple_parser.py keras_frcnn/vgg.py measure_map.py test_frcnn.py train_frcnn.py annotate.txt config.pickle result_annos.csv test.zip train.zip 

# !git commit -m "changed image_dim_ordering to image_data_format"
# !git remote rm origin
# !git remote add origin https://chellabeatrixkiddo:Emma2Jona@github.com/chellabeatrixkiddo/keras-frcnn.git
# !git push origin master'''
# Out:
# [master 285bbb7] changed test_frcnn
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 299 bytes | 149.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/chellabeatrixkiddo/keras-frcnn.git
#    f76de4f..285bbb7  master -> master

# %%
## Example Training Image with annotations

import matplotlib.pyplot as plt
from matplotlib import patches
# %matplotlib inline

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
image = plt.imread('./train/001828.jpg')
plt.imshow(image)
#243,216,489,453
ax.annotate('Top', xy=(489-40,216+20))
rect = patches.Rectangle((243,216), (489-243), (453-216), edgecolor = 'r', facecolor = 'none')
ax.add_patch(rect)
